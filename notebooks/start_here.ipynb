# %% [markdown]
# # Ancient Human–Domesticate Co-evolution Project
# 50,000+ ancient humans + ancient dogs/horses/cattle are ready!
#
# Just run the cells below → everything loads automatically

# %%
MacAfei https://github.com/MacAfei/ancient-human-dog-coevolution.git
# %cd ancient-human-dog-coevolution
# !ls -lh data/

# %%
print("Your ancient DNA project is LIVE!")
print("Next → run the Graph Neural Network notebook")
