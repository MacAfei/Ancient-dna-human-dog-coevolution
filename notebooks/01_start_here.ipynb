# %% [markdown]
# # Ancient Human–Domesticate Co-evolution Project
# Your 50,000+ ancient genomes project is LIVE! 🚀
#
# This notebook loads everything from your GitHub repo automatically.
# Run the cells below – no setup needed.
#
# **Next steps:** After this runs, open 02_graph_construction.ipynb to build the GNN.

# %%
# Clone your repo (data + code loads here)
# !git clone https://github.com/MacAfei/ancient-human-dog-coevolution.git
# %cd ancient-human-dog-coevolution
print("✅ Repo cloned! Now checking your data...")

# %%
# List your uploaded datasets (humans, dogs, etc.)
# !ls -lh data/  # Shows AADR, ancient_dogs, etc.
print("\n📊 Data ready! Shape of human genomes (if loaded):")
# Quick peek at human data (add your .geno file path once uploaded)
# import allel
# gt = allel.read_geno('data/aadr_v54.1.packed.1240K.geno')
# print(f"Humans: {gt.shape[0]} samples, {gt.shape[1]} SNPs")

# %%
print("🎉 Success! Your ancient DNA ML project is running.")
print("Install deps next: !pip install -r requirements.txt")
print("Then train the CoEvoGNN → predict human-dog co-evolution links.")
